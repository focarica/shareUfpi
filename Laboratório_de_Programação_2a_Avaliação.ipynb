# %% [markdown]
# <a href="https://colab.research.google.com/github/focarica/shareUfpi/blob/main/Laborat%C3%B3rio_de_Programa%C3%A7%C3%A3o_2a_Avalia%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Questão 1**

# %%
# !pip install seaborn
import pandas as pd
import seaborn as sn

dados_filmes = pd.read_csv('https://raw.githubusercontent.com/armandossrecife/lp20231/main/top-500-movies.csv')
dados_filmes

correlation = dados_filmes.corr()
plot = sn.heatmap(correlation, annot = True, fmt=".1f", linewidths=.6)
# Out:
# <ipython-input-3-66148a317f20>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = dados_filmes.corr()

# %% [markdown]
# # **Questão 2**

# %%
df = dados_filmes.copy()

top_production_cost = df.sort_values(by='production_cost', ascending=False).head(20)
top_worldwide_gross = df.sort_values(by='worldwide_gross', ascending=False).head(20)

print('Top 20 filmes com maior custo de produção:\n')
print(top_production_cost['title'])
print('\n\n\nTop 20 filmes com maior arrecadação bilheteria mundial:\n')
print(top_worldwide_gross['title'])
# Out:
# Top 20 filmes com maior custo de produção:
#
# 0                               Avengers: Endgame
# 1     Pirates of the Caribbean: On Stranger Tides
# 2                         Avengers: Age of Ultron
# 3            Star Wars Ep. VII: The Force Awakens
# 4                          Avengers: Infinity War
# 5        Pirates of the Caribbean: At World’s End
# 6                                  Justice League
# 7                                         Spectre
# 8     Mission: Impossible Dead Reckoning Part One
# 9                Star Wars: The Rise of Skywalker
# 10                        Solo: A Star Wars Story
# 11                                    John Carter
# 12             Batman v Superman: Dawn of Justice
# 13              Star Wars Ep. VIII: The Last Jedi
# 15                                        Tangled
# 14                                  The Lion King
# 16                                   Spider-Man 3
# 17                     Captain America: Civil War
# ...

# %% [markdown]
# # **Questão 3**

# %%
generos = ['title', 'genre']

print('Gêneros dos 20 filmes com maior custo de produção:\n')
print(top_production_cost[generos])
print('\n\n\nGêneros dos 20 filmes com maior arrecadação bilheteria mundial:\n')
print(top_worldwide_gross[generos])
# Out:
# Gêneros dos 20 filmes com maior custo de produção:
#
#                                           title      genre
# 0                             Avengers: Endgame     Action
# 1   Pirates of the Caribbean: On Stranger Tides  Adventure
# 2                       Avengers: Age of Ultron     Action
# 3          Star Wars Ep. VII: The Force Awakens  Adventure
# 4                        Avengers: Infinity War     Action
# 5      Pirates of the Caribbean: At World’s End  Adventure
# 6                                Justice League     Action
# 7                                       Spectre     Action
# 8   Mission: Impossible Dead Reckoning Part One     Action
# 9              Star Wars: The Rise of Skywalker  Adventure
# 10                      Solo: A Star Wars Story  Adventure
# 11                                  John Carter  Adventure
# 12           Batman v Superman: Dawn of Justice     Action
# 13            Star Wars Ep. VIII: The Last Jedi  Adventure
# ...

# %% [markdown]
# # **Questão 4**

# %%
df = dados_filmes.copy()
top20_worldwide_gross = df.sort_values(by='worldwide_gross', ascending=False).head(20)
media_arrecadacao = top20_worldwide_gross['worldwide_gross'].mean()

print(f'A média de arrecadação mundial dos 20 filmes com maior bilheteria é: {media_arrecadacao:.2f}')
# Out:
# A média de arrecadação mundial dos 20 filmes com maior bilheteria é: 1683804948.85

# %% [markdown]
# # **Questão 5**

# %% [markdown]
# # **Questão 6**

# %% [markdown]
# # **Questão 7**

# %% [markdown]
# # **Questão 8**

# %% [markdown]
# # **Questão 9**

# %% [markdown]
# # **Questão 10**
